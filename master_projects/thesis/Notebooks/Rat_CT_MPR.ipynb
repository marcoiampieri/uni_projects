# %%
# %load_ext autoreload
# %autoreload 2

# Add parent directory to path to find the 'utils' folder
import sys
sys.path.append('..')

import utils.CT_analysis as ct

dicom_folder_path = '../data/rat_CT/'

# %matplotlib inline

# %% [markdown]
# # MULTI-PLANAR REFORMATION

# %%
ct.multi_planar_reformation(dicom_folder_path)
# Out:
# Feet-first scan detected. Z-axis will be flipped for display.
# Voxel Dimensions: dx=0.3027 mm, dy=0.3027 mm, dz=0.6500 mm
# Original Volume Shape (z, y, x): (224, 512, 512)
# interactive(children=(IntSlider(value=112, continuous_update=False, description='Axial Slice (Z):', max=223), …
